# %%
import pandas as pd
import numpy as np

df=pd.read_csv("C:\Vscode\git\mlops\Vehicle-Insurance-project\\notebooks\data.csv")
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
from src.components.eda.summary_statistics import SummaryStatistics

summary=SummaryStatistics(df)
summary.get_overview()
# Out:
# {'shape': (381109, 12),
#  'columns': Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#         'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#         'Policy_Sales_Channel', 'Vintage', 'Response'],
#        dtype='object'),
#  'dtypes': id                        int64
#  Gender                   object
#  Age                       int64
#  Driving_License           int64
#  Region_Code             float64
#  Previously_Insured        int64
#  Vehicle_Age              object
#  Vehicle_Damage           object
#  Annual_Premium          float64
#  Policy_Sales_Channel    float64
#  Vintage                   int64
#  Response                  int64
#  dtype: object}

# %%
summary.get_missing_value_summary()
# Out:
#                       missing_count
# id                                0
# Gender                            0
# Age                               0
# Driving_License                   0
# Region_Code                       0
# Previously_Insured                0
# Vehicle_Age                       0
# Vehicle_Damage                    0
# Annual_Premium                    0
# Policy_Sales_Channel              0
# Vintage                           0
# Response                          0

# %%
from src.components.eda.univariate_analysis import UnivariateAnalyzer,HistogramStrategy
analyzer=UnivariateAnalyzer(HistogramStrategy())
analyzer.analyze(df,'Age')

# %%
from src.components.eda.bivariate_analysis import *
analyze_bivariate=BivariateAnalyzer(ScatterStrategy())
analyze_bivariate.analyze(df,"Age","Region_Code")

# %%
from src.components.eda.multivariate_analysis import MultivariateAnalyzer,CorrelationMatrixStrategy
multi=MultivariateAnalyzer(CorrelationMatrixStrategy())
multi.analyze(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 from src.components.eda.multivariate_analysis import MultivariateAnalyzer,CorrelationMatrixStrategy
#       2 multi=MultivariateAnalyzer(CorrelationMatrixStrategy())
# ----> 3 multi.analyze(df)
#
# File C:\Vscode\git\mlops\Vehicle-Insurance-project\src\components\eda\multivariate_analysis.py:26, in MultivariateAnalyzer.analyze(self, df)
#      25 def analyze(self, df):
# ---> 26     self.strategy.plot(df)
#
# File C:\Vscode\git\mlops\Vehicle-Insurance-project\src\components\eda\multivariate_analysis.py:16, in CorrelationMatrixStrategy.plot(self, df)
#      15 def plot(self, df):
# ---> 16     corr_mtx = df.corr()
#      17     sns.heatmap(corr_mtx, annot=True, cbar=True)
#      18     plt.show()
#
# ...
